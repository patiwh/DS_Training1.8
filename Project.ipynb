# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import sys
import time

from sklearn.ensemble import RandomForestRegressor
from nltk.stem.snowball import SnowballStemmer
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV

# %%
#test files
start_time = time.time()
preprocessed_features = 'vectorised_features.csv'
y_test_file = 'y_test.csv'
y_test_file = 'solutions.csv'

# %%
# function definitions - stemmer, common words, time, test, 
def str_stemmer(s):
    return " ".join([stemmer.stem(word) for word in s.lower().split()])

def str_common_word(str1, str2):
    return sum(int(str2.find(word)>=0) for word in str1.split())

def print_time():
    print("--- %s seconds ---" % (time.time() - start_time))

# %%
#Load data
df_train = pd.read_csv('train.csv', encoding="ISO-8859-1")[:500]
df_test = pd.read_csv('test.csv', encoding='ISO-8859-1')[:500]
df_pro_desc = pd.read_csv('product_descriptions.csv')
df_attr = pd.read_csv('attributes.csv')
print("reading data...")

#Data cleaning
stemmer = SnowballStemmer('english')
n_train = df_train.shape[0]
x_train, x_valid, x_test, y_train, y_valid, y_test = (0,0,0,0,0,0)

df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True)
df_all = pd.merge(df_all, df_pro_desc, how='left', on='product_uid')
df_all = pd.merge(df_all, df_brand, how ='left', on='product_uid')
print("merging data...")

df_all['search_term'] = df_all['search_term'].map(lambda x:str_stemmer(x))
df_all['product_title'] = df_all['product_title'].map(lambda x:str_stemmer(x))
df_all['product_description'] = df_all['product_description'].map(lambda x:str_stemmer(x))
df_all['len_of_query'] = df_all['search_term'].map(lambda x:len(x.split())).astype(np.int64)
df_all['product_info'] = df_all['search_term']+"\t"+df_all['product_description']
df_all['word_in_title'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[1]))
df_all['word_in_description'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[1]))
print("Data has been pre-processed...")

df_all = df_all.drop(['search_term','product_title','product_description','product_info'],axis=1)
df_train = df_all.iloc[:n_train]
df_test = df_all.iloc[n_train:]
id_test = df_test['id']

y_train = df_train['relevance'].values
x_train = df_train.drop(['id','relevance'],axis=1).values
x_test = df_test.drop(['id','relevance'],axis=1).values
print("dropping stuff")

np.savetxt('y_train.csv', y_train, delimiter=",")
np.savetxt("x_train.csv", x_train, fmt= '%s',delimiter=",")
np.savetxt("x_test.csv", x_test, fmt='%s', delimiter=",")
# Out:
# reading data...
# merging data...
# Data has been pre-processed...
# dropping stuff

# %%
x_train = np.genfromtxt('x_train.csv', delimiter=",")
X_test = np.genfromtxt("X_test.csv", delimiter=',')
y_train = np.genfromtxt("y_train.csv", delimiter=',')
n_train = int(0.75*x_train.shape[0])
n_valid = int(0.25*x_train.shape[0])
x_train = x_train[0:n_train, :]

X_valid = x_train[n_train+1:n_train+n_valid, :]

y_train = y_train[0:n_train]

y_valid = y_train[n_train+1:]

# %%
y_test = pd.read_csv('test.csv', encoding='ISO-8859-1')[:500]

# %%
y_test.to_csv('y_test.csv', columns=['id','product_uid','product_title'])

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

y_test = pd.read_csv('test.csv', encoding='ISO-8859-1')

# %%
y_test['product_title'] = y_test['product_title'].astype(object)
y_test['search_term'] = y_test['search_term'].astype(object)

# %%
y_test = y_test.astype(object)

# %%
y_test['product_title'] = y_test['product_title'].apply(word_tokenize)

# %%
y_test['search_term'] = y_test['search_term'].apply(word_tokenize)

# %%
stop = stopwords.words('english')
y_test['product_title'] = y_test['product_title'].apply(lambda x: [item for item in x if item not in stop])
y_test['search_term'] = y_test['search_term'].apply(lambda x: [item for item in x if item not in stop])

# %%
y_test
# Out:
#             id product_uid                                      product_title  \
# 0            1      100001             [Simpson, Strong-Tie, 12-Gauge, Angle]
# 1            4      100001             [Simpson, Strong-Tie, 12-Gauge, Angle]
# 2            5      100001             [Simpson, Strong-Tie, 12-Gauge, Angle]
# 3            6      100001             [Simpson, Strong-Tie, 12-Gauge, Angle]
# 4            7      100001             [Simpson, Strong-Tie, 12-Gauge, Angle]
# 5            8      100001             [Simpson, Strong-Tie, 12-Gauge, Angle]
# 6           10      100003  [STERLING, Ensemble, 33-1/4, ., x, 60, ., x, 7...
# 7           11      100003  [STERLING, Ensemble, 33-1/4, ., x, 60, ., x, 7...
# 8           12      100003  [STERLING, Ensemble, 33-1/4, ., x, 60, ., x, 7...
# 9           13      100004  [Grape, Solar, 265-Watt, Polycrystalline, Sola...
# 10          14      100005  [Delta, Vero, 1-Handle, Shower, Only, Faucet, ...
# 11          15      100005  [Delta, Vero, 1-Handle, Shower, Only, Faucet, ...
# 12          19      100006  [Whirlpool, 1.9, cu, ., ft., Over, Range, Conv...
# 13          22      100006  [Whirlpool, 1.9, cu, ., ft., Over, Range, Conv...
# 14          24      100008  [Teks, #, 10, 1-1/2, ., External, Hex, Flange,...
# 15          25      100009  [House, Fara, 3/4, ., x, 3, ., x, 8, ft., MDF,...
# 16          26      100009  [House, Fara, 3/4, ., x, 3, ., x, 8, ft., MDF,...
# 17          28      100010  [Valley, View, Industries, Metal, Stakes, (, 4...
# 18          29      100010  [Valley, View, Industries, Metal, Stakes, (, 4...
# 19          30      100010  [Valley, View, Industries, Metal, Stakes, (, 4...
# 20          31      100010  [Valley, View, Industries, Metal, Stakes, (, 4...
# 21          32      100010  [Valley, View, Industries, Metal, Stakes, (, 4...
# 22          33      100010  [Valley, View, Industries, Metal, Stakes, (, 4...
# 23          36      100011  [Toro, Personal, Pace, Recycler, 22, ., Variab...
# 24          39      100011  [Toro, Personal, Pace, Recycler, 22, ., Variab...
# 25          40      100011  [Toro, Personal, Pace, Recycler, 22, ., Variab...
# 26          41      100011  [Toro, Personal, Pace, Recycler, 22, ., Variab...
# 27          42      100011  [Toro, Personal, Pace, Recycler, 22, ., Variab...
# 28          43      100011  [Toro, Personal, Pace, Recycler, 22, ., Variab...
# 29          44      100011  [Toro, Personal, Pace, Recycler, 22, ., Variab...
# ...        ...         ...                                                ...
# 166663  240731      224399                 [6-Panel, Composite, Bifold, Door]
# 166664  240732      224400  [Eaton, CSR, 200-Amp, Double, Pole, Main, Brea...
# 166665  240733      224401  [Crown, Bolt, 3/16, ., Zinc, Plated, Steel, Ax...
# 166666  240734      224402        [Dickies, 2-Pocket, Utility, Knife, Sheath]
# 166667  240735      224403  [Patio, Living, Concepts, San, Juan, 60, ., Ou...
# 166668  240736      224404       [Speakman, Emergency, Eyewash, Safety, Sign]
# 166669  240737      224405        [Plantronics, Cable, M12, CS50/CS55, Phone]
# 166670  240738      224406  [Glomar, Vanguard, 9-Light, Textured, Black, C...
# 166671  240739      224407  [Kwikset, Milan, Satin, Nickel, Half-Dummy, Le...
# 166672  240740      224408  [Advanced, Drainage, Systems, 1/2, ., x, 100, ...
# 166673  240741      224409  [Magnavox, 50, ., Class, LED, 1080p, 120, BMR,...
# 166674  240742      224410  [Ekena, Millwork, 7, ., x, 3/4, ., x, 11, ., H...
# 166675  240743      224411  [Minwax, 1, gal, ., Semi-Gloss, Polycrylic, Pr...
# 166676  240744      224412  [Southern, Living, Plant, Collection, 3, Gal, ...
# 166677  240745      224413  [GE, 5.0, cu, ., ft., Gas, Range, Self-Cleanin...
# 166678  240746      224414  [Southwire, 150, ft., 12-3, CU, W/G, Submersib...
# 166679  240747      224415  [Generac, Protector, Series, 15,000-Watt, 120/...
# 166680  240748      224416  [KOHLER, Clearflo, Brass, Toe, Tap, Bath, Drai...
# 166681  240749      224417  [Casablanca, 4-Light, Maiden, Bronze, Ceiling,...
# 166682  240750      224418  [Glidden, Premium, 5-gal, ., #, HDGR19, Fresh,...
# 166683  240751      224419  [Everbilt, 1/8, ., x, 50, ft., Reflective, Bla...
# 166684  240752      224420  [Crown, Bolt, 5/16, ., (, 1/4, in.-20, ), x, 1...
# 166685  240753      224421  [Universal, Tubs, 4.5, ft, ., Right, Drain, Wh...
# 166686  240754      224422  [Everbilt, #, 12, x, 1-1/2, ., Phillips, Brass...
# 166687  240755      224423  [Coastal, Shower, Doors, Legend, Series, 24, ....
# 166688  240756      224424  [stufurhome, Norma, 24, ., W, x, 16, ., D, x, ...
# 166689  240757      224425  [Home, Decorators, Collection, 49, ., D, Aless...
# 166690  240758      224426  [Simpson, Strong-Tie, HB, 3-1/2, x, 14, ., Top...
# 166691  240759      224427  [1/4, ., -20, tpi, x, 1-1/2, ., Stainless, Ste...
# 166692  240760      224428                 [Bosch, 4, ., Bi-Metal, Hole, Saw]
#
#                                   search_term
# 0                       [90, degree, bracket]
# 1                        [metal, l, brackets]
# 2                        [simpson, sku, able]
# 3                     [simpson, strong, ties]
# 4              [simpson, strong, tie, hcc668]
# 5                          [wood, connectors]
# 6                         [bath, shower, kit]
# 7                          [bath, drain, kit]
# 8                   [one, piece, tub, shower]
# 9                              [solar, panel]
# 10      [1, handle, shower, delta, trim, kit]
# 11           [delta, ashland, shower, faucet]
# 12                           [cooking, stove]
# 13                        [microwaves, range]
# 14                    [self, tapping, screws]
# 15                      [3, 1/20door, casing]
# 16                               [door, trim]
# 17                           [anchor, stakes]
# 18                        [landscape, edging]
# 19                             [lawn, edging]
# 20                            [metal, stakes]
# 21                                   [stakes]
# 22                 [steel, landscape, edging]
# 23              [electric, start, gas, mower]
# 24                      [honda, push, mowers]
# 25                             [lawn, mowers]
# 26                               [Lawnmowers]
# 27                              [push, mower]
# 28            [self, propelled, lawn, mowers]
# 29                          [toro, lawn, moa]
# ...                                       ...
# 166663         [bifold, oak, 6, panel, doors]
# 166664      [200, amp, breaker, double, pole]
# 166665                  [axle, locking, nuts]
# 166666                               [sheath]
# 166667               [outdoor, patio, shades]
# 166668                        [safety, signs]
# 166669                         [phone, cable]
# 166670                             [vanguard]
# 166671                        [dummy, handle]
# 166672          [Advanced, drainage, systems]
# 166673                             [led, tvs]
# 166674                           [l, molding]
# 166675                   [minwax, polycrylic]
# 166676                            [camellias]
# 166677                   [black, gas, ranges]
# 166678                    [submersible, wire]
# 166679     [32kw, generac, protector, series]
# 166680                       [bathroom, taps]
# 166681        [ceiling, fan, light, fixtures]
# 166682                              [Peonies]
# 166683                             [paracord]
# 166684               [2, inch, 1/4-20, bolts]
# 166685                         [bath, chairs]
# 166686                           [1/2, brass]
# 166687                 [pivot, shower, doors]
# 166688          [24, whtie, storage, cabinet]
# 166689                   [adirondeck, cusion]
# 166690                                   [hb]
# 166691                         [hex, sockets]
# 166692                   [4, inch, hole, saw]
#
# [166693 rows x 4 columns]

# %%
y_test.to_csv("y_test.csv")

# %%
x_train = pd.read_csv('x_train.csv')
y_train = pd.read_csv('y_train.csv')
# Utility function to report best scores
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")


n_iter_search = 3

param_dist = {"max_depth": [5,10,20,50],

              "max_features": [2,3,4],

              "min_samples_split": [5,10,15],

              "min_samples_leaf": [5,10,15],

              "bootstrap": [True, False]}
random_search = RandomizedSearchCV(rf, param_distributions=param_dist,

                n_iter=n_iter_search)

random_search.fit(X_train, y_train)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))
report(random_search.cv_results_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-0e5baef1deb1> in <module>()
#      29                 n_iter=n_iter_search)
#      30
# ---> 31 random_search.fit(X_train, y_train)
#      32 print("RandomizedSearchCV took %.2f seconds for %d candidates"
#      33       " parameter settings." % ((time() - start), n_iter_search))
#
# NameError: name 'X_train' is not defined
